# %%
# pyspark basic 

# from python array to rdd
rdd = sc.parallelize([{"cat", 1}, {"dog", 1}, {"cat", 2}])
rdd.take(10)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[1]: [{1, &#39;cat&#39;}, {1, &#39;dog&#39;}, {2, &#39;cat&#39;}]</div>

# %%
# map
rdd = sc.parallelize([1, 2, 3, 4, 5])
new_rdd = rdd.map(lambda x: (x + 2))
new_rdd.collect()
# [3, 4, 5, 6, 7]
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[6]: [3, 4, 5, 6, 7]</div>

# %%
# flat map
new_rdd = rdd.flatMap(lambda x: (x - 1, x, x + 1))
new_rdd.collect()
# [0, 1, 2, 1, 2, 3, 2, 3, 4, 3, 4, 5, 4, 5, 6]
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[7]: [0, 1, 2, 1, 2, 3, 2, 3, 4, 3, 4, 5, 4, 5, 6]</div>

# %%
# filter
new_rdd = rdd.filter(lambda x: x > 3)
new_rdd.collect()
# [4, 5]
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[8]: [4, 5]</div>

# %%
# reduce by key
rdd = sc.parallelize([("cat", 1), ("dog", 1), ("cat", 2)])
rdd.reduceByKey(lambda x, y: (x + y)).collect()
# [('cat', 3), ('dog' ,1)]
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[9]: [(&#39;dog&#39;, 1), (&#39;cat&#39;, 3)]</div>

# %%
# group by key
rdd.groupByKey().collect()
rdd.groupByKey().mapValues(list).collect()
# [('cat', [1, 2]), ('dog', [1])]
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[10]: [(&#39;dog&#39;, [1]), (&#39;cat&#39;, [1, 2])]</div>

# %%
# join
people = sc.parallelize([(1, "Mauro"), (2, "Paola"), (3, "Claudia"), (4, "Mario")])
age = sc.parallelize([(1, 36), (2, 30), (4, 71)])
rdd = people.join(age)
rdd.collect()
# [(2, ('Paola', 30)), (4, ('Mario', 71)), (1, ('Mauro', 36))]
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[11]: [(1, (&#39;Mauro&#39;, 36)), (2, (&#39;Paola&#39;, 30)), (4, (&#39;Mario&#39;, 71))]</div>

# %%
# left join
rdd1 = people.leftOuterJoin(age)
rdd1.collect()
# [(2, ('Paola', 30)), (4, ('Mario', 71)), (1, ('Mauro', 36)), (3, ('Claudia', None))]
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[12]: [(1, (&#39;Mauro&#39;, 36)),
#  (2, (&#39;Paola&#39;, 30)),
#  (3, (&#39;Claudia&#39;, None)),
#  (4, (&#39;Mario&#39;, 71))]</div>

# %%
# filter
people = sc.parallelize([(1, "Mauro"), (2, "Paola"), (3, "Claudia"), (4, "Mario")])
age = sc.parallelize([(1, 36), (2, 30), (4, 71)])
rdd1 = people.leftOuterJoin(age)
rdd1.filter(lambda x: x[1][1] is not None and x[1][1] > 30).collect()
# [(4, ('Mario', 71)), (1, ('Mauro', 36))]
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[13]: [(1, (&#39;Mauro&#39;, 36)), (4, (&#39;Mario&#39;, 71))]</div>

# %%
# take
people = sc.parallelize([(1, "Mauro"), (2, "Paola"), (3, "Claudia"), (4, "Mario")])
age = sc.parallelize([(1, 36), (2, 30), (4, 71)])
rdd1 = people.leftOuterJoin(age)
rdd1_filter = rdd1.filter(lambda x: x[1][1] is not None and x[1][1] > 30)
rdd1.take(2)
# [(4, ('Mario', 71)), (1, ('Mauro', 36))]
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[14]: [(1, (&#39;Mauro&#39;, 36)), (2, (&#39;Paola&#39;, 30))]</div>

# %%
# count
people = sc.parallelize([(1, "Mauro"), (2, "Paola"), (3, "Claudia"), (4, "Mario")])
age = sc.parallelize([(1, 36), (2, 30), (4, 71)])
rdd1 = people.leftOuterJoin(age)
rdd1.count()
# 4
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[15]: 4</div>

# %%
# age average
people = sc.parallelize([(1, "Mauro"), (2, "Paola"), (3, "Claudia"), (4, "Mario")])
age = sc.parallelize([(1, 36), (2, 30), (4, 71)])
rdd = people.join(age)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>

# %%
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>

# %%
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>

# %%
# age average
people = sc.parallelize([(1, "Mauro"), (2, "Paola"), (3, "Claudia"), (4, "Mario")])
age = sc.parallelize([(1, 36), (2, 30), (4, 71)])
rdd = people.join(age)

rdd.map(lambda x: x[1][1]).reduce(lambda x, y: x + y) / rdd.count()
# 45.66666666666
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[17]: 45.666666666666664</div>

# %%
rdd.map(lambda x: x[1][1]).sum() / rdd.count()
rdd.map(lambda x: x[1][1]).mean()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[18]: 45.666666666666664</div>

# %%
import urllib.request
urllib.request.urlretrieve("https://raw.githubusercontent.com/mauropelucchi/unimib_masterbi_2021/main/datasets/Indiegogo/ds_project_details_full.csv", "/tmp/ds_project_details_full.csv")
dbutils.fs.mv("file:/tmp/ds_project_details_full.csv","dbfs:/data/ds_project_details_full.csv")
              
urllib.request.urlretrieve("https://github.com/mauropelucchi/unimib_masterbi_2021/blob/main/datasets/Indiegogo/ds_project_location_full.csv", "/tmp/ds_project_location_full.csv")
dbutils.fs.mv("file:/tmp/ds_project_location_full.csv","dbfs:/data/ds_project_location_full.csv")
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[25]: True</div>

# %%
data = spark.read.option("header", "true").option("delimiter",",").csv("dbfs:/data/ds_project_details_full.csv")

data.printSchema()
data.count()
data.createOrReplaceTempView("projects")
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">root
# -- _c0: string (nullable = true)
# -- bullet_point: string (nullable = true)
# -- category: string (nullable = true)
# -- category_url: string (nullable = true)
# -- clickthrough_url: string (nullable = true)
# -- close_date: string (nullable = true)
# -- currency: string (nullable = true)
# -- funds_raised_amount: string (nullable = true)
# -- funds_raised_percent: string (nullable = true)
# -- image_url: string (nullable = true)
# -- is_indemand: string (nullable = true)
# -- is_pre_launch: string (nullable = true)
# -- offered_by: string (nullable = true)
# -- open_date: string (nullable = true)
# -- perk_goal_percentage: string (nullable = true)
# -- perks_claimed: string (nullable = true)
# -- price_offered: string (nullable = true)
# -- price_retail: string (nullable = true)
# -- product_stage: string (nullable = true)
# -- project_id: string (nullable = true)
# -- project_type: string (nullable = true)
# -- tagline: string (nullable = true)
# -- tags: string (nullable = true)
# -- title: string (nullable = true)
#
# </div>

# %%
display(data)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>_c0</th><th>bullet_point</th><th>category</th><th>category_url</th><th>clickthrough_url</th><th>close_date</th><th>currency</th><th>funds_raised_amount</th><th>funds_raised_percent</th><th>image_url</th><th>is_indemand</th><th>is_pre_launch</th><th>offered_by</th><th>open_date</th><th>perk_goal_percentage</th><th>perks_claimed</th><th>price_offered</th><th>price_retail</th><th>product_stage</th><th>project_id</th><th>project_type</th><th>tagline</th><th>tags</th><th>title</th></tr></thead><tbody><tr><td>0</td><td>null</td><td>Film</td><td>/explore/film</td><td>/projects/super-troopers-2</td><td>2015-04-24T23:59:59-07:00</td><td>USD</td><td>4617223</td><td>2.081839</td><td>https://c1.iggcdn.com/indiegogo-media-prod-cld/image/upload/c_fill,f_auto,h_273,w_273/ihngkgslmmpbwcaxurio.jpg</td><td>False</td><td>False</td><td>null</td><td>2015-03-24T10:00:57-07:00</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>1166581</td><td>campaign</td><td>The #SuperTroopers2 campaign is over, but the movie will be out in theaters on 4/20/18!</td><td>['other']</td><td>Super Troopers 2</td></tr><tr><td>1</td><td>null</td><td>Web Series & TV Shows</td><td>/explore/web-series-tv-shows</td><td>/projects/con-man</td><td>2015-04-10T23:59:59-07:00</td><td>USD</td><td>3156178</td><td>7.347458823529411</td><td>https://c1.iggcdn.com/indiegogo-media-prod-cld/image/upload/c_fill,f_auto,h_273,w_273/fxniv9n1jtye9da7gyhq.jpg</td><td>False</td><td>False</td><td>null</td><td>2015-03-10T14:48:01-07:00</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>1143140</td><td>campaign</td><td>A new comedy from Alan Tudyk and Nathan Fillion produced by YOU!</td><td>['other']</td><td>Con Man</td></tr><tr><td>2</td><td>null</td><td>Photography</td><td>/explore/photography</td><td>/projects/the-camera-pack-peter-mckinnon-x-nomatic</td><td>2019-11-14T23:59:59-08:00</td><td>USD</td><td>2677592</td><td>22.86193</td><td>https://c1.iggcdn.com/indiegogo-media-prod-cld/image/upload/c_fill,f_auto,h_273,w_273/hywcddtxwxi88d3imwve.jpg</td><td>False</td><td>False</td><td>null</td><td>2019-11-13T23:59:59-08:00</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>2558245</td><td>campaign</td><td>A Functional Camera Pack for all types of travelers! Just you, one bag, and the adventure!</td><td>['backpacks', 'design', 'luggage', 'professional']</td><td>The Camera Pack: Peter McKinnon X NOMATIC</td></tr><tr><td>3</td><td>null</td><td>Writing & Publishing</td><td>/explore/writing-publishing</td><td>/projects/the-book--28</td><td>2021-01-04T23:59:59-08:00</td><td>USD</td><td>2596877</td><td>293.336625</td><td>https://c1.iggcdn.com/indiegogo-media-prod-cld/image/upload/c_fill,f_auto,h_273,w_273/d7tln1i9lmwwpmamrla9.jpg</td><td>True</td><td>False</td><td>null</td><td>2021-01-03T23:59:59-08:00</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>2650630</td><td>campaign</td><td>The Ultimate Guide To Rebuilding A Civilization. Over 400 pages of detailed illustrations.</td><td>['books', 'burning man', 'design']</td><td>The Book</td></tr><tr><td>4</td><td>null</td><td>Film</td><td>/explore/film</td><td>/projects/code-8-a-film-from-robbie-stephen-amell</td><td>2016-04-23T23:59:59-07:00</td><td>USD</td><td>2501972</td><td>8.600755</td><td>https://c1.iggcdn.com/indiegogo-media-prod-cld/image/upload/c_fill,f_auto,h_273,w_273/rzpfberfrqgm4tcznn76.jpg</td><td>False</td><td>False</td><td>null</td><td>2016-03-22T08:06:31-07:00</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>1676513</td><td>campaign</td><td>Help Robbie & Stephen Amell make their first feature film together!</td><td>['robots']</td><td>Code 8 - a film from Robbie & Stephen Amell</td></tr><tr><td>5</td><td>null</td><td>Film</td><td>/explore/film</td><td>/projects/lazer-team-by-rooster-teeth</td><td>2014-07-06T23:59:59-07: ...

# %%
locations = spark.read.option("header", "true").option("delimiter",",").csv("dbfs:/data/ds_project_location_full.csv")
locations.count()
locations.createOrReplaceTempView("locations")
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
display(locations)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th><!DOCTYPE html></th></tr></thead><tbody><tr><td><html lang="en" data-color-mode="auto" data-light-theme="light" data-dark-theme="dark"></td></tr><tr><td>  <head></td></tr><tr><td>    <meta charset="utf-8"></td></tr><tr><td>  <link rel="dns-prefetch" href="https://github.githubassets.com"></td></tr><tr><td>  <link rel="dns-prefetch" href="https://avatars.githubusercontent.com"></td></tr><tr><td>  <link rel="dns-prefetch" href="https://github-cloud.s3.amazonaws.com"></td></tr><tr><td>  <link rel="dns-prefetch" href="https://user-images.githubusercontent.com/"></td></tr><tr><td>  <link crossorigin="anonymous" media="all" integrity="sha512-B/jj6qcXmAwGUh/FG7mfpfFSb0lW1UpGiufFhzIeC+u3lXE5VDEJQzVxZ3gquw8xjZBNQ6CgWDSgCgjRzqPUgw==" rel="stylesheet" href="https://github.githubassets.com/assets/frameworks-07f8e3eaa717980c06521fc51bb99fa5.css" /></td></tr><tr><td>    <link crossorigin="anonymous" media="all" integrity="sha512-6GPOjKyUzyBU9glXiYr5VayiMkmbK4LqbAjTke98cFsYGAMpdfhoyecnPX/K+2It8hZkRsp26FN+CRtyEJ/oGA==" rel="stylesheet" href="https://github.githubassets.com/assets/behaviors-e863ce8cac94cf2054f60957898af955.css" /></td></tr><tr><td>    <link crossorigin="anonymous" media="all" integrity="sha512-f2KfubpZ4Eg8nwikR8+K0ND4R0evjnYPqjv8dQHShuiypc3SDPYKakEP9hU33tvkjTkCFkMsEjvnXZScK78Khw==" rel="stylesheet" href="https://github.githubassets.com/assets/github-7f629fb9ba59e0483c9f08a447cf8ad0.css" /></td></tr><tr><td>  <script crossorigin="anonymous" defer="defer" integrity="sha512-CzeY4A6TiG4fGZSWZU8FxmzFFmcQFoPpArF0hkH0/J/S7UL4eed/LKEXMQXfTwiG5yEJBI+9BdKG8KQJNbhcIQ==" type="application/javascript" src="https://github.githubassets.com/assets/environment-0b3798e0.js"></script></td></tr><tr><td>    <script crossorigin="anonymous" defer="defer" integrity="sha512-DqYNCH7iUbISz3MHrZQblQWzFkyoyanHdbyINagP5PJaZUBI/ty/b5I50KRwLWqMSur/fpUltEz4XZeRHcr1Yw==" type="application/javascript" src="https://github.githubassets.com/assets/chunk-frameworks-0ea60d08.js"></script></td></tr><tr><td>    <script crossorigin="anonymous" defer="defer" integrity="sha512-YufdcMb4hh5uM2JSDx/MEATxourBQILRY0+74aM14JruGbjAyRYNY7hr/9+MOvY/ItDDo5pyqG/MHZr+5zZKHg==" type="application/javascript" src="https://github.githubassets.com/assets/chunk-vendor-62e7dd70.js"></script></td></tr><tr><td>  <script crossorigin="anonymous" defer="defer" integrity="sha512-Oqv2XvAl5VOAlrAyMihP4k35+VdBeRpk1TerbcBPUr70MaPzA57U34hqrl9z6PUtkdUgGwpATYTUy8/qF11jRA==" type="application/javascript" src="https://github.githubassets.com/assets/behaviors-3aabf65e.js"></script></td></tr><tr><td>    <script crossorigin="anonymous" defer="defer" integrity="sha512-5tWKSr7mhAzSh4Sx5YRFgKftdGxKwHKnOGYw5DlxjHhkQVURYFU3Bk5IMOGMKuAiJTlC3OXYM3xzGcyjzuEFQQ==" type="application/javascript" data-module-id="./chunk-animate-on-scroll.js" data-src="https://github.githubassets.com/assets/chunk-animate-on-scroll-e6d58a4a.js"></script></td></tr><tr><td>    <script crossorigin="anonymous" defer="defer" integrity="sha512-ct3QiK2mvpg7zor9R2psdWnNMM2K32RU4RGRB/7yA5FyZ8H4iY6SNynXc7UaJqzBx6NaReg3GsWJPwW3kgAAig==" type="application/javascript" data-module-id="./chunk-codemirror.js" data-src="https://github.githubassets.com/assets/chunk-codemirror-72ddd088.js"></script></td></tr><tr><td>    <script crossorigin="anonymous" defer="defer" integrity="sha512-M6W/sGLOuJXCIkw+doDl6zl7J9q2DmqdwftQCtyEiZM/UJNGRVQdyKwI/PAMxD12se/wCx3ZcyJs9nz0o0OSVw==" type="application/javascript" data-module-id="./chunk-color-modes.js" data-src="https://github.githubassets.com/assets/chunk-color-modes-33a5bfb0.js"></script></td></tr><tr><td>    <script crossorigin="anonymous" defer="defer" integrity="sha512-71HZu1T5JWqRNF9wrm2NXZAqYVvzxZ8Dvor5U5l/LuEBbGCBX57Sny60Rj+qUZZAvEBGFlNsz179DEn2HFwgVA==" type="application/javascript" data-module-id="./chunk-confetti.js" data-src="https://github.githubassets.com/assets/chunk-confetti-ef51d9bb.js ...

# %%
dx = spark.sql("select * from projects where title is not null")
dy = dx.dropDuplicates()
dy.count()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[40]: 4475</div>

# %%
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
